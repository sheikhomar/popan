# %% [markdown]
# # MNIST 2D

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mpl_colors

import sys
import os
import importlib

sys.path.insert(1, os.path.realpath(os.path.pardir))

import mnist as mnist
import utils as utils
import visualise as visualise

importlib.reload(utils);
importlib.reload(mnist);
importlib.reload(visualise);

import numpy as np
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD

# %%
visualise.mnist_2d()

# %%
X_train, X_test, y_train, y_test = mnist.load_data()
X = np.concatenate((X_train, X_test))
y = np.concatenate((y_train, y_test))

# %%
visualise.pca_variance(X, max_d=100)

# %%
classifier = utils.load_classifier_with_best_params('ncc', 'mnist', True)
X_train_2d = PCA(n_components=2).fit_transform(X_train)
visualise.decision_boundary(classifier, X_train_2d, y_train)

# %%
classifier = utils.load_classifier_with_best_params('nsc2', 'mnist', True)
X_train_2d = PCA(n_components=2).fit_transform(X_train)
visualise.decision_boundary(classifier, X_train_2d, y_train)

# %%
classifier = utils.load_classifier_with_best_params('nn', 'mnist', True)
X_train_2d = PCA(n_components=2).fit_transform(X_train)
visualise.decision_boundary(classifier, X_train_2d, y_train)

# %%
classifier = utils.load_classifier_with_best_params('pmse', 'mnist', True)
X_train_2d = PCA(n_components=2).fit_transform(X_train)
visualise.decision_boundary(classifier, X_train_2d, y_train)
